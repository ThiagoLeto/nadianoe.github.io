# %%
import pandas as pd
import seaborn as sns

df1 = pd.read_csv("datosDeVacunasDadas.csv",sep=",",engine="python" )

grafico = sns.pairplot(df1,hue="grupo_etario",palette="Spectral")

# %%
grafico = sns.pairplot(df1,hue="vacuna",palette="icefire")

# %%
grafico = sns.pairplot(df1,hue="sexo",palette="coolwarm")

# %%
df2 = df1[["jurisdiccion_residencia_id","depto_aplicacion_id","vacuna"]]
grafico = sns.pairplot(df2,hue="vacuna",palette="Spectral")
